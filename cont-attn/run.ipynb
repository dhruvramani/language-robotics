# %%
# %load_ext autoreload
# %autoreload 2

from google.colab import drive

drive.mount("/content/drive")
# %cd /content/drive/My Drive/Projects/lang-robotics/project/cont-attn

uname = "dhruvramani"

# !git config --global user.email "dhruvramani98@gmail.com"
# !git config --global user.name "$uname"

from getpass import getpass
password = getpass('Github Password : ')

# !git remote set-url origin https://$uname:$password@github.com/$uname/language-robotics.git
#!git reset --hard
# !git pull origin master
del password
# !git remote set-url origin https://github.com/$uname/language-robotics.git
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Projects/lang-robotics/project/cont-attn

# %%
# !pip3 install torch numpy transformers Pillow gym matplotlib tensorboardX
# !pip3 install Django django-polymorphic

# %%
# !sudo python3 train.py

# %%
from getpass import getpass
password = getpass('Github Password : ')

# !git remote set-url origin https://$uname:$password@github.com/$uname/language-robotics.git
# !git commit -am "Changes from Drive"
# !git push origin master
del password
# !git remote set-url origin https://github.com/$uname/language-robotics.git
# Out:
# Github Password : ··········
# [master 84303cf] Changes from Drive
#  5 files changed, 13 insertions(+), 13 deletions(-)
#  mode change 100755 => 100644 db/manage.py
# Counting objects: 9, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 816 bytes | 816.00 KiB/s, done.
# Total 9 (delta 8), reused 0 (delta 0)
# remote: Resolving deltas: 100% (8/8), completed with 8 local objects.
# To https://github.com/dhruvramani/language-robotics.git
#    c51f3a1..84303cf  master -> master
